# %% [markdown]
# # Main
#
# Student name: PHAN MANH TUNG
#
# Class: MoSIG M1
#
# Student number: 42202349

# %% [markdown]
# ## Credit German

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
data = pd.read_csv("/content/credit-german.txt", delimiter='\t')

# %%
data.head(3)
# Out:
#   checking_status disc_duration            credit_history    purpose  \
# 0              <0     lo_1_year  critical/other existing    radio/tv
# 1        0<=X<200    up_2_years             existing paid   radio/tv
# 2     no checking     lo_1_year  critical/other existing   education
#
#   disc_amount    savings_status employment     personal_status other_parties  \
# 0   1000_2000  no known savings        >=7         male single          none
# 1     up_2000              <100     1<=X<4  female div/dep/mar          none
# 2     up_2000              <100     4<=X<7         male single          none
#
#   property_magnitude       age other_payment_plans housing existing_credits  \
# 0        real estate      >=55                none     own              two
# 1        real estate       <30                none     own              one
# 2        real estate  30<=X<55                none     own              one
#
#                   job num_dependents own_telephone foreign_worker class
# 0             skilled            one           yes            yes  good
# 1             skilled            one          none            yes   bad
# 2  unskilled resident            two          none            yes  good

# %%
# First we try to see the statistics of the dataset 
data.describe()

'''
Because the apriori algorithm is based on counting frequency, 
we could first identify some fields that could be algorithmically meaningless and noisy to exclude 
+ foreign_worker==yes (freq 963/1000) -> Almost every record is a foreign worker
+ other_payment_plans==none(freq 814/1000) -> Most people do not have other payment plans
+ other_parties==none (freq 907/1000) -> Most people do not have other parties
+ num_dependent==one (845/1000) or two -> Most people has one person depending on them, 15% has two
'''
# Out:
# '\nBecause the apriori algorithm is based on counting frequency, \nwe could first identify some fields that could be algorithmically meaningless and noisy to exclude \n+ foreign_worker==yes (freq 963/1000) -> Almost every record is a foreign worker\n+ other_payment_plans==none(freq 814/1000) -> Most people do not have other payment plans\n+ other_parties==none (freq 907/1000) -> Most people do not have other parties\n+ num_dependent==one (845/1000) or two -> Most people has one person depending on them, 15% has two\n'

# %%
# Make a copy of the dataframe, with the exclusion of the aforementioned fields
df = data.loc[:, ~data.columns.isin(["foreign_worker", "other_payment_plans", "other_parties", "num_dependents"])].copy()

'''
Hint 2: The transactions are not very meaningful without side information e.g., “yes, yes, good” is meaningless
without knowing to which field corresponds each of the values. Propose a smart way of transforming each of
the lines (from the second and until the last one) of the two files in order to have meaningful transactions.
'''

# The dataframe is not about lists of transactions, so that there are some MEANINGLESS values such as "yes", "no", "true"..
# So it is better to add the name of the column to each value with the form: 'column_name==value'
df[df.columns] = df[df.columns].apply(lambda row : str(row.name) + "==" + row)

# turn the df into a list to fit into the model
dataset = df.values.tolist()

# %%
# Association Rules

'''
You probably noticed that a same fixed parameter value may yield a number of frequent itemsets/association
rules that greatly varies from one dataset to another.
For the different datasets, tune the support/confidence/lift values, and filter the antecedents/consequents of
the rules such that you obtain a relatively small number of rules that you find interpretable and useful. The
definitions of the different support, confidence and lift measures are given in the slides ”Rule Mining from
Data”.
In the TP report that you will put on caseine, for each dataset, you will provide the set of extracted rules
that you consider as interpretable and useful, and you will summarize the choices that you have made and the
experiments that you have conducted for setting up the parameters leading to them. The code, outputs and
justifications will be given in a single python file.
'''

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
r = pd.DataFrame(te_ary, columns=te.columns_)

# I choose a low min_support to preserve the class==bad (since there is only 300/1000 records for that class)
frequent_itemsets = apriori(r, min_support=0.15, use_colnames=True) # support > 0.15

# Lift / Conviction > 1 is a good measure to take (if that==1 proposes independency)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.001) 
rules
# Out:
#                           antecedents  \
# 0      (checking_status==no checking)
# 1                     (age==30<=X<55)
# 2                     (age==30<=X<55)
# 3                       (class==good)
# 4                     (age==30<=X<55)
# ...                               ...
# 2095                   (housing==own)
# 2096                   (job==skilled)
# 2097                    (class==good)
# 2098          (existing_credits==one)
# 2099  (credit_history==existing paid)
#
#                                             consequents  antecedent support  \
# 0                                       (age==30<=X<55)               0.394
# 1                        (checking_status==no checking)               0.550
# 2                                         (class==good)               0.550
# 3                                       (age==30<=X<55)               0.700
# 4            (credit_history==critical/other existing )               0.550
# ...                                                 ...                 ...
# 2095  (job==skilled, existing_credits==one, credit_h...               0.713
# 2096  (class==good, existing_credits==one, credit_hi...               0.630
# 2097  (job==skilled, existing_credits==one, credit_h...               0.700
# 2098  (job==skilled, credit_history==existing paid, ...               0.633
# 2099  (job==skilled, existing_credits==one, class==g...               0.530
#
#       consequent support  support  confidence      lift  leverage  conviction
# 0                  0.550    0.246    0.624365  1.135210  0.029300    1.197973
# 1                  0.394    0.246    0.447273  1.135210  0.029300    1.096382
# 2                  0.700    0.409    0.743636  1.062338  0.024000    1.170213
# 3                  0.550    0.409    0.584286  1.062338  0.024000    1.082474
# 4                  0.293    0.189    0.343636  1.172820  0.027850    1.077147
# ...                  ...      ...         ...       ...       ...         ...
# 2095               0.207    0.152    0.213184  1.029873  0.004409    1.007859
# 2096               0.234    0.152    0.241270  1.031068  0.004580    1.009582
# 2097               0.211    0.152    0.217143  1.029113  0.004300    1.007847
# 2098               0.173    0.152    0.240126  1.388014  0.042491    1.088339
# 2099               0.200    0.152    0.286792  1.433962  0.046000    1.121693
#
# [2100 rows x 9 columns]

# %%
# Decision rules

print('''
Reasons to have a good credit: ( lift, conviction > 1 ; confidence > 0.5 ; support threshold is raised to 0.3 )

There are some meaningful reasons for having a "good" class such as: 
+ own a house
+ have a skilled job
+ own a telephone
+ be a single male
+ the age ranges from 30 to 55
''')

result1= rules[(rules['consequents'] == {'class==good'} ) & (rules['confidence'] > 0.5)  & (rules['conviction'] > 0.5)
 & (rules['support'] > 0.3)]
 
result1
# Out:
# Reasons to have a good credit: ( lift, conviction > 1 ; confidence > 0.5 ; support threshold is raised to 0.3 )
#
# There are some meaningful reasons for having a "good" class such as:
# + own a house
# + have a skilled job
# + own a telephone
# + be a single male
# + the age ranges from 30 to 55
#                                       antecedents    consequents  \
# 2                                 (age==30<=X<55)  (class==good)
# 50                 (checking_status==no checking)  (class==good)
# 88                                 (housing==own)  (class==good)
# 90                                 (job==skilled)  (class==good)
# 94                 (personal_status==male single)  (class==good)
# 304                 (age==30<=X<55, housing==own)  (class==good)
# 788         (existing_credits==one, housing==own)  (class==good)
# 808                  (job==skilled, housing==own)  (class==good)
# 814           (own_telephone==none, housing==own)  (class==good)
# 824  (personal_status==male single, housing==own)  (class==good)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 2                 0.550                 0.7    0.409    0.743636  1.062338
# 50                0.394                 0.7    0.348    0.883249  1.261784
# 88                0.713                 0.7    0.527    0.739130  1.055901
# 90                0.630                 0.7    0.444    0.704762  1.006803
# 94                0.548                 0.7    0.402    0.733577  1.047967
# 304               0.417                 0.7    0.324    0.776978  1.109969
# 788               0.438                 0.7    0.311    0.710046  1.014351
# 808               0.452                 0.7    0.342    0.756637  1.080910
# 814               0.433                 0.7    0.319    0.736721  1.052458
# 824               0.408                 0.7    0.314    0.769608  1.099440
#
#      leverage  conviction
# 2      0.0240    1.170213
# 50     0.0722    2.569565
# 88     0.0279    1.150000
# 90     0.0030    1.016129
# 94     0.0184    1.126027
# 304    0.0321    1.345161
# 788    0.0044    1.034646
# 808    0.0256    1.232727
# 814    0.0159    1.139474
# 824    0.0284    1.302128

# %%
print('''
Reasons to have a bad credit: ( lift, conviction > 1 ; support > 0.15 )

There are some meaningful reasons for having a "good" class such as: 
+ existing credits : one
+ do not own a telephone
+ savings status  < 100

It is important to point out the reason for the very low support/confidence values 
because class=='good' has 700/1000 record, so data for class='bad' is thus not so much
Therefore, we do not set a threshold for class=="bad"
''')

result1= rules[(rules['consequents'] == {'class==bad'} )   & (rules['support'] > 0.175)]
result1
# Out:
# Reasons to have a bad credit: ( lift, conviction > 1 ; support > 0.15 )
#
# There are some meaningful reasons for having a "good" class such as:
# + existing credits : one
# + do not own a telephone
# + savings status  < 100
#
# It is important to point out the reason for the very low support/confidence values
# because class=='good' has 700/1000 record, so data for class='bad' is thus not so much
# Therefore, we do not set a threshold for class=="bad"
#                 antecedents   consequents  antecedent support  \
# 68   (disc_amount==up_2000)  (class==bad)               0.568
# 70  (existing_credits==one)  (class==bad)               0.633
# 73    (own_telephone==none)  (class==bad)               0.596
# 75   (savings_status==<100)  (class==bad)               0.603
#
#     consequent support  support  confidence      lift  leverage  conviction
# 68                 0.3    0.179    0.315141  1.050469    0.0086    1.022108
# 70                 0.3    0.200    0.315956  1.053186    0.0101    1.023326
# 73                 0.3    0.187    0.313758  1.045861    0.0082    1.020049
# 75                 0.3    0.217    0.359867  1.199558    0.0361    1.093523

# %%
# Abstract rules : A set of rules for relations among some attributes

result2= rules[(rules['consequents'] != {'class==good'} ) & (rules['consequents'] != {'class==bad'} ) 
& (rules['confidence'] > 0.7)  & (rules['support'] > 0.25)]
result2
# Out:
#                                             antecedents  \
# 12                                      (age==30<=X<55)
# 27                                           (age==<30)
# 28                                           (age==<30)
# 58                       (checking_status==no checking)
# 89                                        (class==good)
# 120                             (existing_credits==one)
# 121                     (credit_history==existing paid)
# 164                          (disc_duration==lo_1_year)
# 166                          (disc_duration==lo_1_year)
# 178                                (employment==1<=X<4)
# 198                             (existing_credits==two)
# 206                                      (job==skilled)
# 210                               (own_telephone==none)
# 212                      (personal_status==male single)
# 215                           (property_magnitude==car)
# 306                        (age==30<=X<55, class==good)
# 410       (age==30<=X<55, personal_status==male single)
# 572         (checking_status==no checking, class==good)
# 670                (existing_credits==one, class==good)
# 671        (credit_history==existing paid, class==good)
# 675        (credit_history==existing paid, class==good)
# 703                 (disc_amount==up_2000, class==good)
# 789                (existing_credits==one, class==good)
# 809                         (job==skilled, class==good)
# 816                  (own_telephone==none, class==good)
# 826         (personal_status==male single, class==good)
# 848                 (savings_status==<100, class==good)
# 902       (existing_credits==one, disc_amount==up_2000)
# 903   (disc_amount==up_2000, credit_history==existin...
# 936               (existing_credits==one, housing==own)
# 937       (credit_history==existing paid, housing==own)
# 940               (job==skilled, existing_credits==one)
# 941       (job==skilled, credit_history==existing paid)
# 945        (existing_credits==one, own_telephone==none)
# 946   (credit_history==existing paid, own_telephone=...
# 968       (existing_credits==one, savings_status==<100)
# 969   (credit_history==existing paid, savings_status...
# 1042  (disc_amount==up_2000, personal_status==male s...
# 1220       (job==skilled, personal_status==male single)
# 1236               (job==skilled, savings_status==<100)
# 1254        (savings_status==<100, own_telephone==none)
#
#                           consequents  antecedent support  consequent support  \
# 12                     (housing==own)               0.550               0.713
# 27                     (job==skilled)               0.371               0.630
# 28              (own_telephone==none)               0.371               0.596
# 58                     (housing==own)               0.394               0.713
# 89                     (housing==own)               0.700               0.713
# 120   (credit_history==existing paid)               0.633               0.530
# 121           (existing_credits==one)               0.530               0.633
# 164                    (housing==own)               0.359               0.713
# 166             (own_telephone==none)               0.359               0.596
# 178                    (housing==own)               0.339               0.713
# 198                    (housing==own)               0.333               0.713
# 206                    (housing==own)               0.630               0.713
# 210                    (housing==own)               0.596               0.713
# 212                    (housing==own)               0.548               0.713
# 215                    (housing==own)               0.332               0.713
# 306                    (housing==own)               0.409               0.713
# 410                    (housing==own)               0.367               0.713
# 572                    (housing==own)               0.348               0.713
# 670   (credit_history==existing paid)               0.433               0.530
# 671           (existing_credits==one)               0.361               0.633
# 675                    (housing==own)               0.361               0.713
# 703                    (housing==own)               0.389               0.713
# 789                    (housing==own)               0.433               0.713
# 809                    (housing==own)               0.444               0.713
# 816                    (housing==own)               0.409               0.713
# 826                    (housing==own)               0.402               0.713
# 848                    (housing==own)               0.386               0.713
# 902   (credit_history==existing paid)               0.361               0.530
# 903           (existing_credits==one)               0.288               0.633
# 936   (credit_history==existing paid)               0.438               0.530
# 937           (existing_credits==one)               0.368               0.633
# 940   (credit_history==existing paid)               0.393               0.530
# 941           (existing_credits==one)               0.338               0.633
# 945   (credit_history==existing paid)               0.387               0.530
# 946           (existing_credits==one)               0.330               0.633
# 968   (credit_history==existing paid)               0.374               0.530
# 969           (existing_credits==one)               0.318               0.633
# 1042                   (housing==own)               0.352               0.713
# 1220                   (housing==own)               0.340               0.713
# 1236                   (housing==own)               0.366               0.713
# 1254                   (housing==own)               0.374               0.713
#
#       support  confidence      lift  leverage  conviction
# and there is no dominative number of each column (this biggest is TYPELAIT==2%MILK with 231/360, which is acceptable)
# Out:
#        TYPELAIT  SELALIMENT SELCONSO ACTIVITESPORT   FUMER HAB_BOISSON
# count       360         360      360           360     360         360
# unique        5           5        6             6       5           4
# top      2%MILK  VERYLITTLE      LOW         NEVER  FORMER     REGULAR
# freq        231         132      123           172     140         213

# %%
# Copy data
df = data.copy()
df[df.columns] = df[df.columns].apply(lambda row : str(row.name) + "==" + row)
dataset = df.values.tolist()

# Encoder
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
r = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# aprori
frequent_itemsets = apriori(r, min_support=0.15, use_colnames=True) 
# unique values (4,5,6) each column -> the best threshold for support is ~1/6

rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.001)

print('''
For this "life habits" dataset, there is no DECISION RULES, since it has no target/decision column
We could only draw out the ABSTRACT RULES, in another word, relations between the activities 

Aprior algorithm with support > 0.15 and lift > 1 yields very good outcome (confidence > 0.3, conviction > 1)

We could see there are very strong and meaningful connections among these habits:
Two-directional connections:
+ (FUMER==REGULAR) <-> (ACTIVITESPORT==NEVER)
+ (ACTIVITESPORT==DAILY)	<-> (HAB_BOISSON==REGULAR)

+ (SELCONSO==LOW|MODERATE) <-> (ACTIVITESPORT==NEVER)

+ (ACTIVITESPORT==DAILY, HAB_BOISSON==REGULAR) <-> (TYPELAIT==2%MILK)

# SELALIMENT and SELCONSO have the same levels
+ (SELALIMENT==NONE) <->	(SELCONSO==VERYLOW)	
+ (SELALIMENT==MODERATE) <->	(SELCONSO==MODERATE)	

One-directional connections:
+ (FUMER==FORMER)	-> (HAB_BOISSON==REGULAR)

..so on..

''')

rules
# Out:
# For this "life habits" dataset, there is no DECISION RULES, since it has no target/decision column
# We could only draw out the ABSTRACT RULES, in another word, relations between the activities
#
# Aprior algorithm with support > 0.15 and lift > 1 yields very good outcome (confidence > 0.3, conviction > 1)
#
# We could see there are very strong and meaningful connections among these habits:
# Two-directional connections:
# + (FUMER==REGULAR) <-> (ACTIVITESPORT==NEVER)
# + (ACTIVITESPORT==DAILY)	<-> (HAB_BOISSON==REGULAR)
#
# + (SELCONSO==LOW|MODERATE) <-> (ACTIVITESPORT==NEVER)
#
# + (ACTIVITESPORT==DAILY, HAB_BOISSON==REGULAR) <-> (TYPELAIT==2%MILK)
#
# # SELALIMENT and SELCONSO have the same levels
# + (SELALIMENT==NONE) <->	(SELCONSO==VERYLOW)
# + (SELALIMENT==MODERATE) <->	(SELCONSO==MODERATE)
#
# One-directional connections:
# + (FUMER==FORMER)	-> (HAB_BOISSON==REGULAR)
#
# ..so on..
#                                      antecedents  \
# 0                         (HAB_BOISSON==REGULAR)
# 1                         (ACTIVITESPORT==DAILY)
# 2                             (TYPELAIT==2%MILK)
# 3                         (ACTIVITESPORT==DAILY)
# 4                               (FUMER==REGULAR)
# 5                         (ACTIVITESPORT==NEVER)
# 6                         (ACTIVITESPORT==NEVER)
# 7                           (HAB_BOISSON==NEVER)
# 8                         (SELALIMENT==MODERATE)
# 9                         (ACTIVITESPORT==NEVER)
# 10                        (ACTIVITESPORT==NEVER)
# 11                               (SELCONSO==LOW)
# 12                        (ACTIVITESPORT==NEVER)
# 13                          (SELCONSO==MODERATE)
# 14                               (FUMER==FORMER)
# 15                        (HAB_BOISSON==REGULAR)
# 16                               (FUMER==FORMER)
# 17                      (SELALIMENT==VERYLITTLE)
# 18                               (FUMER==FORMER)
# 19                               (SELCONSO==LOW)
# 20                               (FUMER==FORMER)
# 21                            (TYPELAIT==2%MILK)
# 22                              (FUMER==REGULAR)
# 23                        (HAB_BOISSON==REGULAR)
# 24                        (SELALIMENT==MODERATE)
# 25                        (HAB_BOISSON==REGULAR)
# 26                        (HAB_BOISSON==REGULAR)
# 27                          (SELCONSO==MODERATE)
# 28                        (HAB_BOISSON==REGULAR)
# 29                            (TYPELAIT==2%MILK)
# 30                        (SELALIMENT==MODERATE)
# 31                          (SELCONSO==MODERATE)
# 32                            (SELALIMENT==NONE)
# 33                           (SELCONSO==VERYLOW)
# 34                            (SELALIMENT==NONE)
# 35                            (TYPELAIT==2%MILK)
# 36                               (SELCONSO==LOW)
# 37                      (SELALIMENT==VERYLITTLE)
# 38                      (SELALIMENT==VERYLITTLE)
# 39                            (TYPELAIT==2%MILK)
# 40                          (SELCONSO==MODERATE)
# 41                            (TYPELAIT==2%MILK)
# 42                           (SELCONSO==VERYLOW)
# 43                            (TYPELAIT==2%MILK)
# 44      (HAB_BOISSON==REGULAR, TYPELAIT==2%MILK)
# 45      (ACTIVITESPORT==DAILY, TYPELAIT==2%MILK)
# 46  (HAB_BOISSON==REGULAR, ACTIVITESPORT==DAILY)
# 47                            (TYPELAIT==2%MILK)
# 48                        (HAB_BOISSON==REGULAR)
# 49                        (ACTIVITESPORT==DAILY)
# 50         (FUMER==FORMER, HAB_BOISSON==REGULAR)
# 51             (FUMER==FORMER, TYPELAIT==2%MILK)
# 52      (HAB_BOISSON==REGULAR, TYPELAIT==2%MILK)
# 53                               (FUMER==FORMER)
# 54                        (HAB_BOISSON==REGULAR)
# 55                            (TYPELAIT==2%MILK)
#
#                                      consequents  antecedent support  \
# 0                         (ACTIVITESPORT==DAILY)            0.591667
# 1                         (HAB_BOISSON==REGULAR)            0.350000
# 2                         (ACTIVITESPORT==DAILY)            0.641667
# 3                             (TYPELAIT==2%MILK)            0.350000
# 4                         (ACTIVITESPORT==NEVER)            0.316667
# 5                               (FUMER==REGULAR)            0.477778
# 6                           (HAB_BOISSON==NEVER)            0.477778
# 7                         (ACTIVITESPORT==NEVER)            0.258333
# 8                         (ACTIVITESPORT==NEVER)            0.269444
# 9                         (SELALIMENT==MODERATE)            0.477778
# 10                               (SELCONSO==LOW)            0.477778
# 11                        (ACTIVITESPORT==NEVER)            0.341667
# 12                          (SELCONSO==MODERATE)            0.477778
# 13                        (ACTIVITESPORT==NEVER)            0.280556
# 14                        (HAB_BOISSON==REGULAR)            0.388889
# 15                               (FUMER==FORMER)            0.591667
# 16                      (SELALIMENT==VERYLITTLE)            0.388889
# 17                               (FUMER==FORMER)            0.366667
# 18                               (SELCONSO==LOW)            0.388889
# 19                               (FUMER==FORMER)            0.341667
# 20                            (TYPELAIT==2%MILK)            0.388889
# 21                               (FUMER==FORMER)            0.641667
# 22                        (HAB_BOISSON==REGULAR)            0.316667
# 23                              (FUMER==REGULAR)            0.591667
# 24                        (HAB_BOISSON==REGULAR)            0.269444
# 25                        (SELALIMENT==MODERATE)            0.591667
# 26                          (SELCONSO==MODERATE)            0.591667
# 27                        (HAB_BOISSON==REGULAR)            0.280556
# 28                            (TYPELAIT==2%MILK)            0.591667
# 29                        (HAB_BOISSON==REGULAR)            0.641667
# 30                          (SELCONSO==MODERATE)            0.269444
# 31                        (SELALIMENT==MODERATE)            0.280556
# 32                           (SELCONSO==VERYLOW)            0.316667
# 33                            (SELALIMENT==NONE)            0.283333
# 34                            (TYPELAIT==2%MILK)            0.316667
# 35                            (SELALIMENT==NONE)            0.641667
# 36                      (SELALIMENT==VERYLITTLE)            0.341667
# 37                               (SELCONSO==LOW)            0.366667
# 38                            (TYPELAIT==2%MILK)            0.366667
# 39                      (SELALIMENT==VERYLITTLE)            0.641667
# 40                            (TYPELAIT==2%MILK)            0.280556
# 41                          (SELCONSO==MODERATE)            0.641667
# 42                            (TYPELAIT==2%MILK)            0.283333
# 43                           (SELCONSO==VERYLOW)            0.641667
# 44                        (ACTIVITESPORT==DAILY)            0.402778
# 45                        (HAB_BOISSON==REGULAR)            0.230556
# 46                            (TYPELAIT==2%MILK)            0.233333
# 47  (HAB_BOISSON==REGULAR, ACTIVITESPORT==DAILY)            0.641667
# 48      (ACTIVITESPORT==DAILY, TYPELAIT==2%MILK)            0.591667
# 49      (HAB_BOISSON==REGULAR, TYPELAIT==2%MILK)            0.350000
# 50                            (TYPELAIT==2%MILK)            0.266667
# 51                        (HAB_BOISSON==REGULAR)            0.266667
# 52                               (FUMER==FORMER)            0.402778
# 53      (HAB_BOISSON==REGULAR, TYPELAIT==2%MILK)            0.388889
# 54             (FUMER==FORMER, TYPELAIT==2%MILK)            0.591667
# 55         (FUMER==FORMER, HAB_BOISSON==REGULAR)            0.641667
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.350000  0.233333    0.394366  1.126761  0.026250    1.073256
# 1             0.591667  0.233333    0.666667  1.126761  0.026250    1.225000
# 2             0.350000  0.230556    0.359307  1.026592  0.005972    1.014527
# 3             0.641667  0.230556    0.658730  1.026592  0.005972    1.050000
# 4             0.477778  0.166667    0.526316  1.101591  0.015370    1.102469
# 5             0.316667  0.166667    0.348837  1.101591  0.015370    1.049405
# 6             0.258333  0.155556    0.325581  1.260315  0.032130    1.099713
# 7             0.477778  0.155556    0.602151  1.260315  0.032130    1.312613
# 8             0.477778  0.155556    0.577320  1.208343  0.026821    1.235501
# 9             0.269444  0.155556    0.325581  1.208343  0.026821    1.083238
# 10            0.341667  0.172222    0.360465  1.055020  0.008981    1.029394
